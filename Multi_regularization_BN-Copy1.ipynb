# %%
conda install pytorch torchvision torchaudio cudatoolkit=11.3 -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   libiconv           conda-forge/linux-64::libiconv-1.16-h516909a_0
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   torchaudio         pytorch/linux-64::torchaudio-0.11.0-py37_cu113
#   torchvision        pytorch/linux-64::torchvision-0.12.0-py37_cu113
#
# The following packages will be UPDATED:
#
#   certifi                          2021.10.8-py37h89c1867_1 --> 2021.10.8-py37h89c1867_2
#   conda                               4.11.0-py37h89c1867_2 --> 4.12.0-py37h89c1867_0
#   openssl                                 1.1.1l-h7f98852_0 --> 1.1.1o-h166bdaf_0
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(144): Could not remove or rename /opt/conda/lib/python3.7/site-packages/torchvision/__pycache__/__init__.cpython-37.pyc.  Please remove this file manually (you may need to reboot to free file handles)
# done
# ERROR conda.core.link:_execute(701): An error occurred while installing package 'pytorch::torchvision-0.12.0-py37_cu113'.
# Rolling back transaction: done
#
# [Errno 13] Permission denied: '/opt/conda/lib/python3.7/site-packages/torchvision/__pycache__/__init__.cpython-37.pyc'
# ()
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

import torch
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms


transform = transforms.Compose([
     transforms.RandomHorizontalFlip(),
     transforms.RandomVerticalFlip(),
     transforms.RandomGrayscale(),
     transforms.RandomPerspective(),
     transforms.ToTensor(),
     transforms.Normalize((0.50, 0.50, 0.50), (0.50, 0.50, 0.50))])

batch_size = 64

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
is_cuda=torch.cuda.is_available()
device=torch.device("cuda" if is_cuda else "cpu")
print(device)
# Out:
# cuda

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# plane  deer  bird truck horse   cat   cat   car   car plane   cat truck   car   dog  deer plane horse plane   car   dog   dog plane  bird horse truck   cat   car truck   cat truck   dog  deer   dog  bird  deer horse   car  ship truck   dog   car   dog   cat truck  bird  bird plane  ship  bird   cat  ship  deer  deer   car  ship plane   car truck   dog  bird   dog  deer   dog  bird

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        
        # Set first filter 
        self.conv1_1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)

        # He initialization:
        nn.init.kaiming_uniform_(self.conv1_1.weight, mode='fan_in', nonlinearity='relu')
        
        self.conv1_2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        nn.init.kaiming_uniform_(self.conv1_2.weight, mode='fan_in', nonlinearity='relu')

        # Set second filter
        self.conv2_1 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        nn.init.kaiming_uniform_(self.conv2_1.weight, mode='fan_in', nonlinearity='relu')

        self.conv2_2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        nn.init.kaiming_uniform_(self.conv2_2.weight, mode='fan_in', nonlinearity='relu')

        # Set third filter
        self.conv3_1 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        nn.init.kaiming_uniform_(self.conv3_1.weight, mode='fan_in', nonlinearity='relu')
        
        self.conv3_2 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1)
        nn.init.kaiming_uniform_(self.conv3_2.weight, mode='fan_in', nonlinearity='relu')
      
        # Definebatch Normalization
        self.BN1 = nn.BatchNorm2d(32)
        self.BN2 = nn.BatchNorm2d(64)
        self.BN3 = nn.BatchNorm2d(128)
        self.BN4 = nn.BatchNorm1d(120)
        self.BN5 = nn.BatchNorm1d(84)

        # Define proportion or neurons to dropout
        self.dropout1 = nn.Dropout(0.2)
        self.dropout2 = nn.Dropout(0.3)
        self.dropout3 = nn.Dropout(0.4)
        self.dropout4 = nn.Dropout(0.5)
        self.dropout5 = nn.Dropout(0.6)

        self.pool = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(2048, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.BN1(self.conv1_2(self.BN1(self.conv1_1(x))))))
        x = self.dropout1(x)
        x = self.pool(F.relu(self.BN2(self.conv2_2(self.BN2(self.conv2_1(x))))))
        x = self.dropout2(x)
        x = self.pool(F.relu(self.BN3(self.conv3_2(self.BN3(self.conv3_1(x))))))
        x = self.dropout3(x)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.BN4(self.fc1(x)))
        x = self.dropout4(x)
        x = F.relu(self.BN5(self.fc2(x)))
        x = self.dropout5(x)
        x = self.fc3(x)
        return x

net = Net().to(device)

import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)


epoch = 400
TL = [0 for x in range(epoch)] #train loss
Tacc = [0 for x in range(epoch)] #train accuracy
VL = [0 for x in range(epoch)] #validation loss
Vacc = [0 for x in range(epoch)] #validation accuracy

for ep in range(epoch):  # loop over the dataset multiple times

    running_loss = 0.0
    train_acc = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs,labels=inputs.to(device),labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()

        pred=outputs.argmax(dim=1,keepdim=True)
        train_acc += ((pred.eq(labels.view_as(pred)).sum().item())/(50000))
        
        # if i % 2000 == 1999:    # print every 2000 mini-batches
        #     print('[%d, %5d] loss: %.3f' %
        #           (epoch + 1, i + 1, running_loss / 2000))
        #     running_loss = 0.0

    valid_loss = 0.0
    valid_acc = 0.0
    net.eval()     # Optional when not using Model Specific layer
    for inputs, labels in testloader:
        inputs,labels=inputs.to(device),labels.to(device)
        # Forward Pass
        outputs = net(inputs)
        # Find the Loss
        loss = criterion(outputs,labels)
        # Calculate Loss
        valid_loss += loss.item()

        pred=outputs.argmax(dim=1,keepdim=True)
        valid_acc += ((pred.eq(labels.view_as(pred)).sum().item())/(10000))

    TL[ep] = running_loss  
    Tacc[ep] = train_acc   
    VL[ep] = valid_loss
    Vacc[ep] = valid_acc

    print(f'Epoch {ep+1}/{epoch} \t Training Loss: {round(running_loss / len(trainloader),4)} \t Validation Loss: {round(valid_loss / len(testloader),4)} \t Training Accuracy: {round(train_acc,4)} \t Validation Loss:{round(valid_acc,4)}')

print('Finished Training')
# Out:
# Epoch 1/400 	 Training Loss: 2.1999 	 Validation Loss: 2.3964 	 Training Accuracy: 0.1747 	 Validation Loss:0.117
# Epoch 2/400 	 Training Loss: 1.8316 	 Validation Loss: 1.7211 	 Training Accuracy: 0.3148 	 Validation Loss:0.3569
# Epoch 3/400 	 Training Loss: 1.6631 	 Validation Loss: 1.5878 	 Training Accuracy: 0.3779 	 Validation Loss:0.4072
# Epoch 4/400 	 Training Loss: 1.5463 	 Validation Loss: 1.4918 	 Training Accuracy: 0.4269 	 Validation Loss:0.448
# Epoch 5/400 	 Training Loss: 1.4644 	 Validation Loss: 1.4178 	 Training Accuracy: 0.4633 	 Validation Loss:0.4791
# Epoch 6/400 	 Training Loss: 1.38 	 Validation Loss: 1.3686 	 Training Accuracy: 0.4977 	 Validation Loss:0.4943
# Epoch 7/400 	 Training Loss: 1.3219 	 Validation Loss: 1.3128 	 Training Accuracy: 0.5181 	 Validation Loss:0.5199
# Epoch 8/400 	 Training Loss: 1.2624 	 Validation Loss: 1.258 	 Training Accuracy: 0.5424 	 Validation Loss:0.5455
# Epoch 9/400 	 Training Loss: 1.2179 	 Validation Loss: 1.211 	 Training Accuracy: 0.5617 	 Validation Loss:0.5689
# Epoch 10/400 	 Training Loss: 1.1845 	 Validation Loss: 1.1505 	 Training Accuracy: 0.5738 	 Validation Loss:0.5865
# Epoch 11/400 	 Training Loss: 1.1433 	 Validation Loss: 1.162 	 Training Accuracy: 0.5888 	 Validation Loss:0.5886
# Epoch 12/400 	 Training Loss: 1.1119 	 Validation Loss: 1.1106 	 Training Accuracy: 0.6001 	 Validation Loss:0.6021
# Epoch 13/400 	 Training Loss: 1.0813 	 Validation Loss: 1.0668 	 Training Accuracy: 0.613 	 Validation Loss:0.6174
# Epoch 14/400 	 Training Loss: 1.0589 	 Validation Loss: 1.0473 	 Training Accuracy: 0.6186 	 Validation Loss:0.6238
# Epoch 15/400 	 Training Loss: 1.026 	 Validation Loss: 1.0355 	 Training Accuracy: 0.6318 	 Validation Loss:0.6303
# Epoch 16/400 	 Training Loss: 1.0128 	 Validation Loss: 1.0482 	 Training Accuracy: 0.637 	 Validation Loss:0.6294
# Epoch 17/400 	 Training Loss: 0.9876 	 Validation Loss: 1.032 	 Training Accuracy: 0.6463 	 Validation Loss:0.6322
# Epoch 18/400 	 Training Loss: 0.9658 	 Validation Loss: 0.9926 	 Training Accuracy: 0.6545 	 Validation Loss:0.6461
# Epoch 19/400 	 Training Loss: 0.947 	 Validation Loss: 0.971 	 Training Accuracy: 0.6605 	 Validation Loss:0.6535
# Epoch 20/400 	 Training Loss: 0.9338 	 Validation Loss: 0.9627 	 Training Accuracy: 0.6672 	 Validation Loss:0.6581
# Epoch 21/400 	 Training Loss: 0.9188 	 Validation Loss: 0.9431 	 Training Accuracy: 0.6705 	 Validation Loss:0.6697
# Epoch 22/400 	 Training Loss: 0.9077 	 Validation Loss: 0.9751 	 Training Accuracy: 0.6729 	 Validation Loss:0.6567
# Epoch 23/400 	 Training Loss: 0.8919 	 Validation Loss: 0.9291 	 Training Accuracy: 0.6806 	 Validation Loss:0.6719
# Epoch 24/400 	 Training Loss: 0.8759 	 Validation Loss: 0.925 	 Training Accuracy: 0.6876 	 Validation Loss:0.6693
# Epoch 25/400 	 Training Loss: 0.8634 	 Validation Loss: 0.9244 	 Training Accuracy: 0.6925 	 Validation Loss:0.6689
# Epoch 26/400 	 Training Loss: 0.8492 	 Validation Loss: 0.931 	 Training Accuracy: 0.6971 	 Validation Loss:0.6756
# Epoch 27/400 	 Training Loss: 0.839 	 Validation Loss: 0.8847 	 Training Accuracy: 0.7013 	 Validation Loss:0.684
# Epoch 28/400 	 Training Loss: 0.8312 	 Validation Loss: 0.9038 	 Training Accuracy: 0.7039 	 Validation Loss:0.6775
# Epoch 29/400 	 Training Loss: 0.8184 	 Validation Loss: 0.8672 	 Training Accuracy: 0.7091 	 Validation Loss:0.6912
# Epoch 30/400 	 Training Loss: 0.8091 	 Validation Loss: 0.8509 	 Training Accuracy: 0.7102 	 Validation Loss:0.6961
# Epoch 31/400 	 Training Loss: 0.7988 	 Validation Loss: 0.8614 	 Training Accuracy: 0.7157 	 Validation Loss:0.6979
# Epoch 32/400 	 Training Loss: 0.7945 	 Validation Loss: 0.8542 	 Training Accuracy: 0.7184 	 Validation Loss:0.7027
# Epoch 33/400 	 Training Loss: 0.7773 	 Validation Loss: 0.8483 	 Training Accuracy: 0.7228 	 Validation Loss:0.6978
# Epoch 34/400 	 Training Loss: 0.7748 	 Validation Loss: 0.83 	 Training Accuracy: 0.7251 	 Validation Loss:0.7087
# Epoch 35/400 	 Training Loss: 0.7693 	 Validation Loss: 0.8218 	 Training Accuracy: 0.7276 	 Validation Loss:0.7073
# Epoch 36/400 	 Training Loss: 0.7614 	 Validation Loss: 0.8331 	 Training Accuracy: 0.7307 	 Validation Loss:0.7028
# Epoch 37/400 	 Training Loss: 0.7548 	 Validation Loss: 0.8236 	 Training Accuracy: 0.7297 	 Validation Loss:0.7116
# Epoch 38/400 	 Training Loss: 0.7461 	 Validation Loss: 0.8198 	 Training Accuracy: 0.7339 	 Validation Loss:0.7123
# Epoch 39/400 	 Training Loss: 0.7404 	 Validation Loss: 0.824 	 Training Accuracy: 0.738 	 Validation Loss:0.7093
# Epoch 40/400 	 Training Loss: 0.7283 	 Validation Loss: 0.8024 	 Training Accuracy: 0.7415 	 Validation Loss:0.7211
# Epoch 41/400 	 Training Loss: 0.7288 	 Validation Loss: 0.8256 	 Training Accuracy: 0.7398 	 Validation Loss:0.7083
# Epoch 42/400 	 Training Loss: 0.7168 	 Validation Loss: 0.8316 	 Training Accuracy: 0.7454 	 Validation Loss:0.7064
# Epoch 43/400 	 Training Loss: 0.721 	 Validation Loss: 0.8236 	 Training Accuracy: 0.7442 	 Validation Loss:0.7086
# Epoch 44/400 	 Training Loss: 0.699 	 Validation Loss: 0.814 	 Training Accuracy: 0.7512 	 Validation Loss:0.7109
# Epoch 45/400 	 Training Loss: 0.6996 	 Validation Loss: 0.8274 	 Training Accuracy: 0.7521 	 Validation Loss:0.704
# Epoch 46/400 	 Training Loss: 0.6939 	 Validation Loss: 0.7805 	 Training Accuracy: 0.7537 	 Validation Loss:0.7252
# Epoch 47/400 	 Training Loss: 0.6865 	 Validation Loss: 0.785 	 Training Accuracy: 0.7569 	 Validation Loss:0.7255
# Epoch 48/400 	 Training Loss: 0.6844 	 Validation Loss: 0.7813 	 Training Accuracy: 0.7563 	 Validation Loss:0.7251
# Epoch 49/400 	 Training Loss: 0.6823 	 Validation Loss: 0.7623 	 Training Accuracy: 0.7585 	 Validation Loss:0.7303
# Epoch 50/400 	 Training Loss: 0.6725 	 Validation Loss: 0.7694 	 Training Accuracy: 0.7611 	 Validation Loss:0.7326
# Epoch 51/400 	 Training Loss: 0.67 	 Validation Loss: 0.774 	 Training Accuracy: 0.7634 	 Validation Loss:0.7293
# Epoch 52/400 	 Training Loss: 0.6679 	 Validation Loss: 0.7785 	 Training Accuracy: 0.7646 	 Validation Loss:0.7269
# Epoch 53/400 	 Training Loss: 0.6567 	 Validation Loss: 0.7614 	 Training Accuracy: 0.7671 	 Validation Loss:0.7367
# Epoch 54/400 	 Training Loss: 0.6524 	 Validation Loss: 0.7806 	 Training Accuracy: 0.768 	 Validation Loss:0.7297
# Epoch 55/400 	 Training Loss: 0.6452 	 Validation Loss: 0.7615 	 Training Accuracy: 0.7709 	 Validation Loss:0.7317
# Epoch 56/400 	 Training Loss: 0.6491 	 Validation Loss: 0.7882 	 Training Accuracy: 0.7706 	 Validation Loss:0.7236
# Epoch 57/400 	 Training Loss: 0.6423 	 Validation Loss: 0.7494 	 Training Accuracy: 0.7718 	 Validation Loss:0.7351
# Epoch 58/400 	 Training Loss: 0.6396 	 Validation Loss: 0.7632 	 Training Accuracy: 0.774 	 Validation Loss:0.7323
# Epoch 59/400 	 Training Loss: 0.6344 	 Validation Loss: 0.7604 	 Training Accuracy: 0.7753 	 Validation Loss:0.7374
# Epoch 60/400 	 Training Loss: 0.6265 	 Validation Loss: 0.7595 	 Training Accuracy: 0.779 	 Validation Loss:0.7318
# Epoch 61/400 	 Training Loss: 0.6336 	 Validation Loss: 0.7338 	 Training Accuracy: 0.7748 	 Validation Loss:0.7409
# Epoch 62/400 	 Training Loss: 0.6187 	 Validation Loss: 0.7595 	 Training Accuracy: 0.7812 	 Validation Loss:0.7389
# Epoch 63/400 	 Training Loss: 0.6178 	 Validation Loss: 0.7395 	 Training Accuracy: 0.7813 	 Validation Loss:0.7387
# Epoch 64/400 	 Training Loss: 0.6127 	 Validation Loss: 0.7312 	 Training Accuracy: 0.7821 	 Validation Loss:0.7455
# Epoch 65/400 	 Training Loss: 0.6088 	 Validation Loss: 0.748 	 Training Accuracy: 0.7856 	 Validation Loss:0.7459
# Epoch 66/400 	 Training Loss: 0.6048 	 Validation Loss: 0.7541 	 Training Accuracy: 0.7861 	 Validation Loss:0.7434
# Epoch 67/400 	 Training Loss: 0.6001 	 Validation Loss: 0.731 	 Training Accuracy: 0.7859 	 Validation Loss:0.7446
# Epoch 68/400 	 Training Loss: 0.5968 	 Validation Loss: 0.774 	 Training Accuracy: 0.7898 	 Validation Loss:0.7389
# Epoch 69/400 	 Training Loss: 0.5929 	 Validation Loss: 0.7595 	 Training Accuracy: 0.791 	 Validation Loss:0.742
# Epoch 70/400 	 Training Loss: 0.6019 	 Validation Loss: 0.7414 	 Training Accuracy: 0.7874 	 Validation Loss:0.744
# Epoch 71/400 	 Training Loss: 0.5856 	 Validation Loss: 0.7262 	 Training Accuracy: 0.7909 	 Validation Loss:0.7493
# Epoch 72/400 	 Training Loss: 0.5845 	 Validation Loss: 0.7219 	 Training Accuracy: 0.7919 	 Validation Loss:0.7518
# Epoch 73/400 	 Training Loss: 0.5854 	 Validation Loss: 0.7503 	 Training Accuracy: 0.7926 	 Validation Loss:0.7388
# Epoch 74/400 	 Training Loss: 0.5764 	 Validation Loss: 0.7379 	 Training Accuracy: 0.7941 	 Validation Loss:0.7462
# Epoch 75/400 	 Training Loss: 0.5755 	 Validation Loss: 0.7103 	 Training Accuracy: 0.7963 	 Validation Loss:0.7573
# Epoch 76/400 	 Training Loss: 0.5677 	 Validation Loss: 0.7411 	 Training Accuracy: 0.7994 	 Validation Loss:0.7449
# Epoch 77/400 	 Training Loss: 0.5674 	 Validation Loss: 0.7277 	 Training Accuracy: 0.8001 	 Validation Loss:0.7527
# Epoch 78/400 	 Training Loss: 0.5653 	 Validation Loss: 0.734 	 Training Accuracy: 0.8011 	 Validation Loss:0.7469
# Epoch 79/400 	 Training Loss: 0.5635 	 Validation Loss: 0.7272 	 Training Accuracy: 0.8008 	 Validation Loss:0.7495
# Epoch 80/400 	 Training Loss: 0.5646 	 Validation Loss: 0.7257 	 Training Accuracy: 0.8008 	 Validation Loss:0.7516
# Epoch 81/400 	 Training Loss: 0.5553 	 Validation Loss: 0.7284 	 Training Accuracy: 0.8043 	 Validation Loss:0.7506
# Epoch 82/400 	 Training Loss: 0.5571 	 Validation Loss: 0.7071 	 Training Accuracy: 0.8046 	 Validation Loss:0.756
# Epoch 83/400 	 Training Loss: 0.5575 	 Validation Loss: 0.7053 	 Training Accuracy: 0.8036 	 Validation Loss:0.7567
# Epoch 84/400 	 Training Loss: 0.5551 	 Validation Loss: 0.7102 	 Training Accuracy: 0.8054 	 Validation Loss:0.755
# Epoch 85/400 	 Training Loss: 0.5502 	 Validation Loss: 0.7079 	 Training Accuracy: 0.806 	 Validation Loss:0.7589
# Epoch 86/400 	 Training Loss: 0.545 	 Validation Loss: 0.717 	 Training Accuracy: 0.8093 	 Validation Loss:0.7574
# Epoch 87/400 	 Training Loss: 0.5406 	 Validation Loss: 0.7279 	 Training Accuracy: 0.8093 	 Validation Loss:0.7518
# Epoch 88/400 	 Training Loss: 0.5368 	 Validation Loss: 0.7082 	 Training Accuracy: 0.8099 	 Validation Loss:0.755
# Epoch 89/400 	 Training Loss: 0.5365 	 Validation Loss: 0.7331 	 Training Accuracy: 0.8107 	 Validation Loss:0.753
# Epoch 90/400 	 Training Loss: 0.5407 	 Validation Loss: 0.7236 	 Training Accuracy: 0.8093 	 Validation Loss:0.7535
# Epoch 91/400 	 Training Loss: 0.5333 	 Validation Loss: 0.7226 	 Training Accuracy: 0.8123 	 Validation Loss:0.7575
# Epoch 92/400 	 Training Loss: 0.5307 	 Validation Loss: 0.724 	 Training Accuracy: 0.813 	 Validation Loss:0.7514
# Epoch 93/400 	 Training Loss: 0.5258 	 Validation Loss: 0.699 	 Training Accuracy: 0.8144 	 Validation Loss:0.7604
# Epoch 94/400 	 Training Loss: 0.5293 	 Validation Loss: 0.7259 	 Training Accuracy: 0.8146 	 Validation Loss:0.7571
# Epoch 95/400 	 Training Loss: 0.5229 	 Validation Loss: 0.7136 	 Training Accuracy: 0.8155 	 Validation Loss:0.7589
# Epoch 96/400 	 Training Loss: 0.5154 	 Validation Loss: 0.726 	 Training Accuracy: 0.82 	 Validation Loss:0.7551
# Epoch 97/400 	 Training Loss: 0.5176 	 Validation Loss: 0.7131 	 Training Accuracy: 0.8164 	 Validation Loss:0.7606
# Epoch 98/400 	 Training Loss: 0.5074 	 Validation Loss: 0.7251 	 Training Accuracy: 0.8222 	 Validation Loss:0.7561
# Epoch 99/400 	 Training Loss: 0.517 	 Validation Loss: 0.7066 	 Training Accuracy: 0.8171 	 Validation Loss:0.7564
# Epoch 100/400 	 Training Loss: 0.5121 	 Validation Loss: 0.7256 	 Training Accuracy: 0.8197 	 Validation Loss:0.7596
# Epoch 101/400 	 Training Loss: 0.5092 	 Validation Loss: 0.7254 	 Training Accuracy: 0.8188 	 Validation Loss:0.7567
# Epoch 102/400 	 Training Loss: 0.5064 	 Validation Loss: 0.7193 	 Training Accuracy: 0.819 	 Validation Loss:0.7576
# Epoch 103/400 	 Training Loss: 0.5081 	 Validation Loss: 0.6941 	 Training Accuracy: 0.8206 	 Validation Loss:0.7644
# Epoch 104/400 	 Training Loss: 0.5045 	 Validation Loss: 0.7045 	 Training Accuracy: 0.8224 	 Validation Loss:0.7593
# Epoch 105/400 	 Training Loss: 0.4958 	 Validation Loss: 0.6854 	 Training Accuracy: 0.8252 	 Validation Loss:0.7694
# Epoch 106/400 	 Training Loss: 0.4977 	 Validation Loss: 0.7077 	 Training Accuracy: 0.824 	 Validation Loss:0.7668
# Epoch 107/400 	 Training Loss: 0.4928 	 Validation Loss: 0.707 	 Training Accuracy: 0.8261 	 Validation Loss:0.77
# Epoch 108/400 	 Training Loss: 0.4956 	 Validation Loss: 0.7017 	 Training Accuracy: 0.8267 	 Validation Loss:0.764
# Epoch 109/400 	 Training Loss: 0.4903 	 Validation Loss: 0.7081 	 Training Accuracy: 0.8277 	 Validation Loss:0.7636
# Epoch 110/400 	 Training Loss: 0.4924 	 Validation Loss: 0.6987 	 Training Accuracy: 0.8278 	 Validation Loss:0.7628
# Epoch 111/400 	 Training Loss: 0.4881 	 Validation Loss: 0.7035 	 Training Accuracy: 0.8277 	 Validation Loss:0.7664
# Epoch 112/400 	 Training Loss: 0.4891 	 Validation Loss: 0.7032 	 Training Accuracy: 0.8286 	 Validation Loss:0.7667
# Epoch 113/400 	 Training Loss: 0.4855 	 Validation Loss: 0.728 	 Training Accuracy: 0.8286 	 Validation Loss:0.763
# Epoch 114/400 	 Training Loss: 0.4864 	 Validation Loss: 0.7077 	 Training Accuracy: 0.8304 	 Validation Loss:0.7639
# Epoch 115/400 	 Training Loss: 0.4816 	 Validation Loss: 0.7125 	 Training Accuracy: 0.8292 	 Validation Loss:0.763
# Epoch 116/400 	 Training Loss: 0.4827 	 Validation Loss: 0.7104 	 Training Accuracy: 0.8305 	 Validation Loss:0.7585
# Epoch 117/400 	 Training Loss: 0.4753 	 Validation Loss: 0.7108 	 Training Accuracy: 0.8344 	 Validation Loss:0.766
# Epoch 118/400 	 Training Loss: 0.4722 	 Validation Loss: 0.6922 	 Training Accuracy: 0.8337 	 Validation Loss:0.7689
# Epoch 119/400 	 Training Loss: 0.4809 	 Validation Loss: 0.7118 	 Training Accuracy: 0.8311 	 Validation Loss:0.7652
# Epoch 120/400 	 Training Loss: 0.4735 	 Validation Loss: 0.7046 	 Training Accuracy: 0.8338 	 Validation Loss:0.772
# Epoch 121/400 	 Training Loss: 0.4712 	 Validation Loss: 0.6845 	 Training Accuracy: 0.8341 	 Validation Loss:0.7729
# Epoch 122/400 	 Training Loss: 0.4698 	 Validation Loss: 0.6933 	 Training Accuracy: 0.8345 	 Validation Loss:0.7702
# Epoch 123/400 	 Training Loss: 0.4666 	 Validation Loss: 0.7182 	 Training Accuracy: 0.835 	 Validation Loss:0.7643
# Epoch 124/400 	 Training Loss: 0.4668 	 Validation Loss: 0.7069 	 Training Accuracy: 0.8348 	 Validation Loss:0.7666
# Epoch 125/400 	 Training Loss: 0.4668 	 Validation Loss: 0.7262 	 Training Accuracy: 0.8348 	 Validation Loss:0.7624
# Epoch 126/400 	 Training Loss: 0.4609 	 Validation Loss: 0.6771 	 Training Accuracy: 0.8376 	 Validation Loss:0.7722
# Epoch 127/400 	 Training Loss: 0.4661 	 Validation Loss: 0.719 	 Training Accuracy: 0.8374 	 Validation Loss:0.7596
# Epoch 128/400 	 Training Loss: 0.4604 	 Validation Loss: 0.7028 	 Training Accuracy: 0.8383 	 Validation Loss:0.7698
# Epoch 129/400 	 Training Loss: 0.4635 	 Validation Loss: 0.7207 	 Training Accuracy: 0.8362 	 Validation Loss:0.7676
# Epoch 130/400 	 Training Loss: 0.4607 	 Validation Loss: 0.72 	 Training Accuracy: 0.8376 	 Validation Loss:0.7678
# Epoch 131/400 	 Training Loss: 0.4606 	 Validation Loss: 0.6887 	 Training Accuracy: 0.8385 	 Validation Loss:0.7677
# Epoch 132/400 	 Training Loss: 0.4565 	 Validation Loss: 0.6927 	 Training Accuracy: 0.8388 	 Validation Loss:0.7749
# Epoch 133/400 	 Training Loss: 0.4517 	 Validation Loss: 0.6795 	 Training Accuracy: 0.84 	 Validation Loss:0.7755
# Epoch 134/400 	 Training Loss: 0.4483 	 Validation Loss: 0.7271 	 Training Accuracy: 0.843 	 Validation Loss:0.7715
# Epoch 135/400 	 Training Loss: 0.4494 	 Validation Loss: 0.7306 	 Training Accuracy: 0.8425 	 Validation Loss:0.761
# Epoch 136/400 	 Training Loss: 0.4475 	 Validation Loss: 0.7212 	 Training Accuracy: 0.8421 	 Validation Loss:0.7702
# Epoch 137/400 	 Training Loss: 0.4446 	 Validation Loss: 0.6973 	 Training Accuracy: 0.8425 	 Validation Loss:0.769
# Epoch 138/400 	 Training Loss: 0.4472 	 Validation Loss: 0.6992 	 Training Accuracy: 0.8437 	 Validation Loss:0.7718
# Epoch 139/400 	 Training Loss: 0.447 	 Validation Loss: 0.7025 	 Training Accuracy: 0.8417 	 Validation Loss:0.7704
# Epoch 140/400 	 Training Loss: 0.4438 	 Validation Loss: 0.7023 	 Training Accuracy: 0.8438 	 Validation Loss:0.7678
# Epoch 141/400 	 Training Loss: 0.4375 	 Validation Loss: 0.7029 	 Training Accuracy: 0.8454 	 Validation Loss:0.776
# Epoch 142/400 	 Training Loss: 0.4409 	 Validation Loss: 0.6901 	 Training Accuracy: 0.8437 	 Validation Loss:0.7747
# Epoch 143/400 	 Training Loss: 0.4379 	 Validation Loss: 0.687 	 Training Accuracy: 0.8452 	 Validation Loss:0.7745
# Epoch 144/400 	 Training Loss: 0.4403 	 Validation Loss: 0.7163 	 Training Accuracy: 0.8457 	 Validation Loss:0.7721
# Epoch 145/400 	 Training Loss: 0.4363 	 Validation Loss: 0.7098 	 Training Accuracy: 0.8477 	 Validation Loss:0.7734
# Epoch 146/400 	 Training Loss: 0.4332 	 Validation Loss: 0.7037 	 Training Accuracy: 0.8491 	 Validation Loss:0.7707
# Epoch 147/400 	 Training Loss: 0.441 	 Validation Loss: 0.689 	 Training Accuracy: 0.8458 	 Validation Loss:0.7707
# Epoch 148/400 	 Training Loss: 0.434 	 Validation Loss: 0.7051 	 Training Accuracy: 0.8463 	 Validation Loss:0.7693
# Epoch 149/400 	 Training Loss: 0.4326 	 Validation Loss: 0.7118 	 Training Accuracy: 0.8472 	 Validation Loss:0.7701
# Epoch 150/400 	 Training Loss: 0.4337 	 Validation Loss: 0.6946 	 Training Accuracy: 0.8473 	 Validation Loss:0.7726
# Epoch 151/400 	 Training Loss: 0.4265 	 Validation Loss: 0.716 	 Training Accuracy: 0.8497 	 Validation Loss:0.7694
# Epoch 152/400 	 Training Loss: 0.428 	 Validation Loss: 0.6989 	 Training Accuracy: 0.8501 	 Validation Loss:0.7695
# Epoch 153/400 	 Training Loss: 0.4341 	 Validation Loss: 0.7057 	 Training Accuracy: 0.8464 	 Validation Loss:0.7706
# Epoch 154/400 	 Training Loss: 0.431 	 Validation Loss: 0.7073 	 Training Accuracy: 0.848 	 Validation Loss:0.7749
# Epoch 155/400 	 Training Loss: 0.4256 	 Validation Loss: 0.7205 	 Training Accuracy: 0.8497 	 Validation Loss:0.7703
# Epoch 156/400 	 Training Loss: 0.4271 	 Validation Loss: 0.6905 	 Training Accuracy: 0.8498 	 Validation Loss:0.7715
# Epoch 157/400 	 Training Loss: 0.426 	 Validation Loss: 0.7064 	 Training Accuracy: 0.8523 	 Validation Loss:0.7715
# Epoch 158/400 	 Training Loss: 0.423 	 Validation Loss: 0.6853 	 Training Accuracy: 0.8518 	 Validation Loss:0.7822
# Epoch 159/400 	 Training Loss: 0.4199 	 Validation Loss: 0.6936 	 Training Accuracy: 0.8534 	 Validation Loss:0.7809
# Epoch 160/400 	 Training Loss: 0.4246 	 Validation Loss: 0.6759 	 Training Accuracy: 0.8513 	 Validation Loss:0.778
# Epoch 161/400 	 Training Loss: 0.4174 	 Validation Loss: 0.6798 	 Training Accuracy: 0.852 	 Validation Loss:0.7769
# Epoch 162/400 	 Training Loss: 0.4175 	 Validation Loss: 0.7058 	 Training Accuracy: 0.8524 	 Validation Loss:0.7673
# Epoch 163/400 	 Training Loss: 0.422 	 Validation Loss: 0.7007 	 Training Accuracy: 0.852 	 Validation Loss:0.7733
# Epoch 164/400 	 Training Loss: 0.4175 	 Validation Loss: 0.7173 	 Training Accuracy: 0.853 	 Validation Loss:0.7676
# Epoch 165/400 	 Training Loss: 0.4176 	 Validation Loss: 0.6735 	 Training Accuracy: 0.8546 	 Validation Loss:0.7809
# Epoch 166/400 	 Training Loss: 0.4152 	 Validation Loss: 0.6816 	 Training Accuracy: 0.8518 	 Validation Loss:0.7778
# Epoch 167/400 	 Training Loss: 0.4134 	 Validation Loss: 0.6882 	 Training Accuracy: 0.8549 	 Validation Loss:0.7803
# Epoch 168/400 	 Training Loss: 0.4092 	 Validation Loss: 0.7277 	 Training Accuracy: 0.8573 	 Validation Loss:0.7726
# Epoch 169/400 	 Training Loss: 0.4087 	 Validation Loss: 0.6959 	 Training Accuracy: 0.8572 	 Validation Loss:0.7768
# Epoch 170/400 	 Training Loss: 0.409 	 Validation Loss: 0.7061 	 Training Accuracy: 0.8581 	 Validation Loss:0.7765
# Epoch 171/400 	 Training Loss: 0.4103 	 Validation Loss: 0.7028 	 Training Accuracy: 0.8552 	 Validation Loss:0.7747
# Epoch 172/400 	 Training Loss: 0.4061 	 Validation Loss: 0.6936 	 Training Accuracy: 0.8549 	 Validation Loss:0.7767
# Epoch 173/400 	 Training Loss: 0.4117 	 Validation Loss: 0.707 	 Training Accuracy: 0.8544 	 Validation Loss:0.7772
# Epoch 174/400 	 Training Loss: 0.4049 	 Validation Loss: 0.6924 	 Training Accuracy: 0.8581 	 Validation Loss:0.7767
# Epoch 175/400 	 Training Loss: 0.4059 	 Validation Loss: 0.7183 	 Training Accuracy: 0.8586 	 Validation Loss:0.7767
# Epoch 176/400 	 Training Loss: 0.4103 	 Validation Loss: 0.7151 	 Training Accuracy: 0.857 	 Validation Loss:0.7784
# Epoch 177/400 	 Training Loss: 0.408 	 Validation Loss: 0.7007 	 Training Accuracy: 0.8565 	 Validation Loss:0.7785
# Epoch 178/400 	 Training Loss: 0.3972 	 Validation Loss: 0.6739 	 Training Accuracy: 0.8608 	 Validation Loss:0.7812
# Epoch 179/400 	 Training Loss: 0.4028 	 Validation Loss: 0.6791 	 Training Accuracy: 0.8591 	 Validation Loss:0.7809
# Epoch 180/400 	 Training Loss: 0.402 	 Validation Loss: 0.6892 	 Training Accuracy: 0.8586 	 Validation Loss:0.7779
# Epoch 181/400 	 Training Loss: 0.3917 	 Validation Loss: 0.703 	 Training Accuracy: 0.863 	 Validation Loss:0.77
# Epoch 182/400 	 Training Loss: 0.4043 	 Validation Loss: 0.6778 	 Training Accuracy: 0.8579 	 Validation Loss:0.7801
# Epoch 183/400 	 Training Loss: 0.3981 	 Validation Loss: 0.7181 	 Training Accuracy: 0.8614 	 Validation Loss:0.7698
# Epoch 184/400 	 Training Loss: 0.3937 	 Validation Loss: 0.6939 	 Training Accuracy: 0.862 	 Validation Loss:0.7803
# Epoch 185/400 	 Training Loss: 0.4008 	 Validation Loss: 0.7012 	 Training Accuracy: 0.8585 	 Validation Loss:0.7732
# Epoch 186/400 	 Training Loss: 0.3923 	 Validation Loss: 0.7125 	 Training Accuracy: 0.8615 	 Validation Loss:0.775
# Epoch 187/400 	 Training Loss: 0.3929 	 Validation Loss: 0.7182 	 Training Accuracy: 0.8614 	 Validation Loss:0.7761
# Epoch 188/400 	 Training Loss: 0.3988 	 Validation Loss: 0.6971 	 Training Accuracy: 0.8605 	 Validation Loss:0.7805
# Epoch 189/400 	 Training Loss: 0.392 	 Validation Loss: 0.7106 	 Training Accuracy: 0.8633 	 Validation Loss:0.779
# Epoch 190/400 	 Training Loss: 0.3936 	 Validation Loss: 0.6937 	 Training Accuracy: 0.8628 	 Validation Loss:0.7835
# Epoch 191/400 	 Training Loss: 0.3914 	 Validation Loss: 0.698 	 Training Accuracy: 0.8632 	 Validation Loss:0.7767
# Epoch 192/400 	 Training Loss: 0.3925 	 Validation Loss: 0.7035 	 Training Accuracy: 0.8628 	 Validation Loss:0.7789
# Epoch 193/400 	 Training Loss: 0.3889 	 Validation Loss: 0.7323 	 Training Accuracy: 0.8628 	 Validation Loss:0.7724
# Epoch 194/400 	 Training Loss: 0.3886 	 Validation Loss: 0.6958 	 Training Accuracy: 0.8638 	 Validation Loss:0.78
# Epoch 195/400 	 Training Loss: 0.3847 	 Validation Loss: 0.6789 	 Training Accuracy: 0.8662 	 Validation Loss:0.7822
# Epoch 196/400 	 Training Loss: 0.3898 	 Validation Loss: 0.7036 	 Training Accuracy: 0.8631 	 Validation Loss:0.7759
# Epoch 197/400 	 Training Loss: 0.3892 	 Validation Loss: 0.6951 	 Training Accuracy: 0.8642 	 Validation Loss:0.7812
# Epoch 198/400 	 Training Loss: 0.3849 	 Validation Loss: 0.6939 	 Training Accuracy: 0.866 	 Validation Loss:0.7789
# Epoch 199/400 	 Training Loss: 0.381 	 Validation Loss: 0.7114 	 Training Accuracy: 0.8676 	 Validation Loss:0.778
# Epoch 200/400 	 Training Loss: 0.3841 	 Validation Loss: 0.6966 	 Training Accuracy: 0.8641 	 Validation Loss:0.7823
# Epoch 201/400 	 Training Loss: 0.3827 	 Validation Loss: 0.7026 	 Training Accuracy: 0.8673 	 Validation Loss:0.7779
# Epoch 202/400 	 Training Loss: 0.3846 	 Validation Loss: 0.7031 	 Training Accuracy: 0.8654 	 Validation Loss:0.7772
# Epoch 203/400 	 Training Loss: 0.3786 	 Validation Loss: 0.706 	 Training Accuracy: 0.867 	 Validation Loss:0.7828
# Epoch 204/400 	 Training Loss: 0.3773 	 Validation Loss: 0.6926 	 Training Accuracy: 0.8676 	 Validation Loss:0.784
# Epoch 205/400 	 Training Loss: 0.3799 	 Validation Loss: 0.713 	 Training Accuracy: 0.8678 	 Validation Loss:0.7798
# Epoch 206/400 	 Training Loss: 0.378 	 Validation Loss: 0.7183 	 Training Accuracy: 0.8681 	 Validation Loss:0.7772
# Epoch 207/400 	 Training Loss: 0.3777 	 Validation Loss: 0.6807 	 Training Accuracy: 0.8676 	 Validation Loss:0.7882
# Epoch 208/400 	 Training Loss: 0.3733 	 Validation Loss: 0.6997 	 Training Accuracy: 0.8685 	 Validation Loss:0.7808
# Epoch 209/400 	 Training Loss: 0.3737 	 Validation Loss: 0.6897 	 Training Accuracy: 0.8687 	 Validation Loss:0.7857
# Epoch 210/400 	 Training Loss: 0.381 	 Validation Loss: 0.7141 	 Training Accuracy: 0.8662 	 Validation Loss:0.7785
# Epoch 211/400 	 Training Loss: 0.3787 	 Validation Loss: 0.7005 	 Training Accuracy: 0.8658 	 Validation Loss:0.7826
# Epoch 212/400 	 Training Loss: 0.377 	 Validation Loss: 0.6949 	 Training Accuracy: 0.8665 	 Validation Loss:0.7829
# Epoch 213/400 	 Training Loss: 0.371 	 Validation Loss: 0.7105 	 Training Accuracy: 0.8697 	 Validation Loss:0.7823
# Epoch 214/400 	 Training Loss: 0.3735 	 Validation Loss: 0.6774 	 Training Accuracy: 0.8709 	 Validation Loss:0.7878
# Epoch 215/400 	 Training Loss: 0.3663 	 Validation Loss: 0.7112 	 Training Accuracy: 0.8729 	 Validation Loss:0.7789
# Epoch 216/400 	 Training Loss: 0.3743 	 Validation Loss: 0.6962 	 Training Accuracy: 0.8678 	 Validation Loss:0.7836
# Epoch 217/400 	 Training Loss: 0.3742 	 Validation Loss: 0.6912 	 Training Accuracy: 0.8681 	 Validation Loss:0.7815
# Epoch 218/400 	 Training Loss: 0.3688 	 Validation Loss: 0.7099 	 Training Accuracy: 0.871 	 Validation Loss:0.7768
# Epoch 219/400 	 Training Loss: 0.3731 	 Validation Loss: 0.7154 	 Training Accuracy: 0.8701 	 Validation Loss:0.7778
# Epoch 220/400 	 Training Loss: 0.3652 	 Validation Loss: 0.7065 	 Training Accuracy: 0.8716 	 Validation Loss:0.7815
# Epoch 221/400 	 Training Loss: 0.3698 	 Validation Loss: 0.7056 	 Training Accuracy: 0.8713 	 Validation Loss:0.7782
# Epoch 222/400 	 Training Loss: 0.3694 	 Validation Loss: 0.6874 	 Training Accuracy: 0.8702 	 Validation Loss:0.7812
# Epoch 223/400 	 Training Loss: 0.3717 	 Validation Loss: 0.7068 	 Training Accuracy: 0.8705 	 Validation Loss:0.7795
# Epoch 224/400 	 Training Loss: 0.3641 	 Validation Loss: 0.7113 	 Training Accuracy: 0.8715 	 Validation Loss:0.7768
# Epoch 225/400 	 Training Loss: 0.3658 	 Validation Loss: 0.7329 	 Training Accuracy: 0.8724 	 Validation Loss:0.7765
# Epoch 226/400 	 Training Loss: 0.3679 	 Validation Loss: 0.7129 	 Training Accuracy: 0.8701 	 Validation Loss:0.7844
# Epoch 227/400 	 Training Loss: 0.3631 	 Validation Loss: 0.6983 	 Training Accuracy: 0.8735 	 Validation Loss:0.7836
# Epoch 228/400 	 Training Loss: 0.3675 	 Validation Loss: 0.7171 	 Training Accuracy: 0.87 	 Validation Loss:0.777
# Epoch 229/400 	 Training Loss: 0.3614 	 Validation Loss: 0.7101 	 Training Accuracy: 0.8747 	 Validation Loss:0.7871
# Epoch 230/400 	 Training Loss: 0.3611 	 Validation Loss: 0.702 	 Training Accuracy: 0.874 	 Validation Loss:0.7821
# Epoch 231/400 	 Training Loss: 0.3616 	 Validation Loss: 0.7345 	 Training Accuracy: 0.8733 	 Validation Loss:0.7797
# Epoch 232/400 	 Training Loss: 0.3632 	 Validation Loss: 0.72 	 Training Accuracy: 0.8742 	 Validation Loss:0.7834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5560/3738324492.py in <module>
#      90
#      91         # forward + backward + optimize
# ---> 92         outputs = net(inputs)
#      93         loss = criterion(outputs, labels)
#      94         loss.backward()
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_5560/3738324492.py in forward(self, x)
#      50
#      51     def forward(self, x):
# ---> 52         x = self.pool(F.relu(self.BN1(self.conv1_2(self.BN1(self.conv1_1(x))))))
#      53         x = self.dropout1(x)
#      54         x = self.pool(F.relu(self.BN2(self.conv2_2(self.BN2(self.conv2_1(x))))))
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
# --> 447         return self._conv_forward(input, self.weight, self.bias)
#     448
#     449 class Conv3d(_ConvNd):
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     442                             _pair(0), self.dilation, self.groups)
#     443         return F.conv2d(input, weight, bias, self.stride,
# --> 444                         self.padding, self.dilation, self.groups)
#     445
#     446     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
import sys
from matplotlib import pyplot
nTL= [x / len(trainloader) for x in TL]
nVL = [x / len(testloader) for x in VL]
# plot diagnostic learning curves
# plot loss
pyplot.subplot(211)
pyplot.title('Cross Entropy Loss')
pyplot.plot(nTL, color='blue', label='train')
pyplot.plot(nVL, color='orange', label='test')
pyplot.legend(loc="upper right")
# plot accuracy
pyplot.subplot(212)
pyplot.title('Classification Accuracy')
pyplot.plot(Tacc, color='blue', label='train')
pyplot.plot(Vacc, color='orange', label='test')
pyplot.legend(loc="lower right")
pyplot.tight_layout()
# save plot to file
# filename = sys.argv[0].split('/')[-1]
# pyplot.savefig(filename + '_plot.png')
# pyplot.close()

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data 
        images,labels=images.to(device),labels.to(device)
        outputs = net(images)    
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1

# print accuracy for each class
overall_acc = []
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname, 
                                                   accuracy))
# Out:
# Accuracy for class plane is: 86.4 %
# Accuracy for class car   is: 85.6 %
# Accuracy for class bird  is: 76.0 %
# Accuracy for class cat   is: 57.9 %
# Accuracy for class deer  is: 73.2 %
# Accuracy for class dog   is: 64.2 %
# Accuracy for class frog  is: 82.4 %
# Accuracy for class horse is: 81.5 %
# Accuracy for class ship  is: 88.2 %
# Accuracy for class truck is: 80.4 %
